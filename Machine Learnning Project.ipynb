# %%
import pandas as pd
import numpy as np
pd.readcsv()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 7              FDP10          NaN          Low Fat         0.127470
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 10             FDY07       11.800          Low Fat         0.000000
# 11             FDA03       18.500          Regular         0.045464
# 12             FDX32       15.100          Regular         0.100014
# ...

# %%
df.mean()
# Out:
# Item_Weight                    12.857645
# Item_Visibility                 0.066132
# Item_MRP                      140.992782
# Outlet_Establishment_Year    1997.831867
# Item_Outlet_Sales            2181.288914
# dtype: float64

# %%
df["Item_Fat_Content"].replace(['Low Fat','Regular','low fat','reg'],['LF','Reg','LF','Reg'],inplace=True)
df['Outlet_Size'].fillna(value='Medium',inplace=True)
a=df.fillna(df.mean())
a
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15     9.300000               LF         0.016047
# 1              DRC01     5.920000              Reg         0.019278
# 2              FDN15    17.500000               LF         0.016760
# 3              FDX07    19.200000              Reg         0.000000
# 4              NCD19     8.930000               LF         0.000000
# 5              FDP36    10.395000              Reg         0.000000
# 6              FDO10    13.650000              Reg         0.012741
# 7              FDP10    12.857645               LF         0.127470
# 8              FDH17    16.200000              Reg         0.016687
# 9              FDU28    19.200000              Reg         0.094450
# 10             FDY07    11.800000               LF         0.000000
# 11             FDA03    18.500000              Reg         0.045464
# 12             FDX32    15.100000              Reg         0.100014
# ...

# %%
a.axes
# Out:
# [RangeIndex(start=0, stop=8523, step=1),
#  Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#         'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#         'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#         'Outlet_Type', 'Item_Outlet_Sales'],
#        dtype='object')]

# %%
b=a.head(50)
b
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0            FDA15     9.300000               LF         0.016047
# 1            DRC01     5.920000              Reg         0.019278
# 2            FDN15    17.500000               LF         0.016760
# 3            FDX07    19.200000              Reg         0.000000
# 4            NCD19     8.930000               LF         0.000000
# 5            FDP36    10.395000              Reg         0.000000
# 6            FDO10    13.650000              Reg         0.012741
# 7            FDP10    12.857645               LF         0.127470
# 8            FDH17    16.200000              Reg         0.016687
# 9            FDU28    19.200000              Reg         0.094450
# 10           FDY07    11.800000               LF         0.000000
# 11           FDA03    18.500000              Reg         0.045464
# 12           FDX32    15.100000              Reg         0.100014
# ...

# %%
a.shape
# Out:
# (50, 12)

# %%
a['Item_Outlet_Sales'].value_counts()
# Out:
# 1587.2672    1
# 556.6088     1
# 3791.0652    1
# 718.3982     1
# 2085.2856    1
# 2797.6916    1
# 1589.2646    1
# 1547.3192    1
# 2150.5340    1
# 2428.8384    1
# 2527.3768    1
# 5815.0972    1
# 6768.5228    1
# 388.1614     1
# 443.4228     1
# 1076.5986    1
# 2748.4224    1
# 3435.5280    1
# 2097.2700    1
# 3735.1380    1
# 3775.0860    1
# 214.3876     1
# 2187.1530    1
# 1065.2800    1
# 4022.7636    1
# 1977.4260    1
# 343.5528     1
# 1516.0266    1
# 1621.8888    1
# 2145.2076    1
# 358.2004     1
# 2180.4950    1
# 4064.0432    1
# 373.5138     1
# 780.3176     1
# 3068.0064    1
# 2741.7644    1
# 2303.6680    1
# 2174.5028    1
# 4710.5350    1
# 163.7868     1
# 732.3800     1
# 125.8362     1
# 994.7052     1
# 178.4344     1
# 1609.9044    1
# 4078.0250    1
# 2576.6460    1
# 308.9312     1
# 838.9080     1
# Name: Item_Outlet_Sales, dtype: int64

# %%
a.T

# %%
a.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-df7bc805137c> in <module>
# ----> 1 a.columns
#
# NameError: name 'a' is not defined

# %%
import seaborn as sns
import matplotlib.pyplot as plt
b.plot(kind='scatter',x='Item_Weight',y='Item_Visibility')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-e91c858e272d> in <module>
#       1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
# ----> 3 b.plot(kind='scatter',x='Item_Weight',y='Item_Visibility')
#       4 plt.show()
#
# NameError: name 'b' is not defined

# %%
sns.set_style("whitegrid")
sns.FacetGrid(b,hue='Item_Fat_Content',size=6).map(plt.scatter,'Item_Weight','Item_Visibility').add_legend()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.set_style("whitegrid")
sns.FacetGrid(b,hue='Item_Fat_Content',size=6).map(plt.scatter,'Item_Weight','Item_MRP').add_legend()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.set_style("whitegrid")
sns.FacetGrid(b,hue='Outlet_Size',size=6).map(plt.scatter,'Outlet_Establishment_Year','Item_Weight').add_legend()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.set_style("whitegrid")
sns.FacetGrid(b,hue='Item_Fat_Content',size=6).map(plt.scatter,'Outlet_Establishment_Year','Item_Weight').add_legend()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(b,hue='Outlet_Size',size=3).add_legend
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# ...

# %%
sns.pairplot(b,hue='Item_Fat_Content',size=3).add_legend
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # FEATURE ENGINEERING

# %%
sns.boxplot(x='Outlet_Size',y='Outlet_Establishment_Year',data=b)
plt.show()

# %%
sns.boxplot(x='Outlet_Size',y='Item_Weight',data=b)
plt.show()

# %%
sns.boxplot(x='Outlet_Size',y='Item_Visibility',data=b)
plt.show()

# %%
sns.violinplot(x='Outlet_Size',y='Outlet_Establishment_Year',data=b,size=10)
plt.show()

# %%
sns.countplot(x='Outlet_Size',data=b)
plt.show()

# %%
plt.hist(x='Outlet_Establishment_Year',data=High,bins=10)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-7601ce374844> in <module>
# ----> 1 plt.hist(x='Outlet_Establishment_Year',data=High,bins=10)
#       2 plt.show()
#
# NameError: name 'High' is not defined

# %%
sns.swarmplot(x='Outlet_Size',y='Outlet_Establishment_Year',data=b)
plt.show()

# %%
sns.swarmplot(x='Outlet_Size',y='Item_Weight',data=b)
plt.show()

# %%
sns.swarmplot(x='Outlet_Size',y='Item_Visibility',data=b)
plt.show()

# %%
sns.stripplot(x='Outlet_Size',y='Outlet_Establishment_Year',data=b)
plt.show()

# %%
sns.FacetGrid(b,hue='Outlet_Size',size=6).map(sns.distplot,'Outlet_Establishment_Year').add_legend();
plt.show()
sns.distplot(High['Outlet_Establishment_Year'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-1b0177cf2ecd> in <module>
#       1 sns.FacetGrid(b,hue='Outlet_Size',size=6).map(sns.distplot,'Outlet_Establishment_Year').add_legend();
#       2 plt.show()
# ----> 3 sns.distplot(High['Outlet_Establishment_Year'])
#       4 plt.show()
#
# NameError: name 'High' is not defined

# %%
sns.FacetGrid(b,hue='Outlet_Size',size=6).map(sns.distplot,'Item_Visibility').add_legend();
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c49b2593aaa1> in <module>
# ----> 1 sns.FacetGrid(b,hue='Outlet_Size',size=6).map(sns.distplot,'Item_Visibility').add_legend();
#       2 plt.show()
#
# NameError: name 'sns' is not defined

# %%
sns.FacetGrid(b,hue='Outlet_Size',size=6).map(sns.distplot,'Item_Weight').add_legend();
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.kdeplot(High['Outlet_Establishment_Year'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a566d02f9452> in <module>
# ----> 1 sns.kdeplot(High['Outlet_Establishment_Year'])
#       2 plt.show()
#
# NameError: name 'sns' is not defined

# %%
sns.kdeplot(High['Outlet_Establishment_Year'],cumulative=true)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8b925020d6ec> in <module>
# ----> 1 sns.kdeplot(High['Outlet_Establishment_Year'],cumulative=true)
#       2 plt.show()
#
# NameError: name 'sns' is not defined

# %%
sns.jointplot(x='Outlet_Establishment_Year',y='Item_Weight',data='High',kind="kde",size=10);
plt.show();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7699e6135fd8> in <module>
# ----> 1 sns.jointplot(x='Outlet_Establishment_Year',y='Item_Weight',data='High',kind="kde",size=10);
#       2 plt.show();
#
# NameError: name 'sns' is not defined

# %%
list=[a['Outlet_Establishment_Year']]
print (list)
# Out:
# [0       1999
# 1       2009
# 2       1999
# 3       1998
# 4       1987
# 5       2009
# 6       1987
# 7       1985
# 8       2002
# 9       2007
# 10      1999
# 11      1997
# 12      1999
# 13      1997
# 14      1987
# 15      1997
# 16      2009
# 17      1999
# 18      1985
# 19      2004
# 20      1987
# 21      1985
# 22      2004
# 23      1985
# 24      1997
# 25      2007
# 26      2004
# 27      1987
# 28      1998
# 29      1985
#         ...
# 8493    2007
# 8494    2007
# 8495    2004
# 8496    2007
# 8497    2004
# 8498    2009
# 8499    2004
# 8500    2007
# 8501    2007
# 8502    2002
# 8503    2004
# 8504    1985
# 8505    2009
# 8506    2009
# 8507    2004
# 8508    2002
# 8509    1998
# 8510    2004
# 8511    2009
# 8512    1987
# 8513    2004
# 8514    2002
# 8515    2009
# 8516    2009
# 8517    1997
# 8518    1987
# 8519    2002
# 8520    2004
# 8521    2009
# 8522    1997
# Name: Outlet_Establishment_Year, Length: 8523, dtype: int64]

# %% [markdown]
# # Detecting OutLiers

# %%
## This method works only with continuous variable
for feature in continuous_features:
    data=df.copy()
    if 0 in data[feature].unique():
        pass
    else:
        data[feature]=np.log(data[feature])
        data.boxplot(column=feature)
        plt.ylabel(feature)
        plt.title(feature)
        plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-dd288195105c> in <module>
#       1 ## This method works only with continuous variable
# ----> 2 for feature in continuous_features:
#       3     data=df.copy()
#       4     if 0 in data[feature].unique():
#       5         pass
#
# NameError: name 'continuous_features' is not defined
